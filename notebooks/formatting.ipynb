# %%
import pandas as pd

# %%
px_data = pd.read_csv('../px_data.csv')

# %%
px_data
# Out:
#             date     open     high        low    close     adjClose   volume  \
# 0     2025-02-14  1044.95  1064.50  1041.6900  1058.60  1058.600000  3133301
# 1     2025-02-13  1026.63  1045.99  1025.1000  1043.69  1043.690000  3476100
# 2     2025-02-12  1005.49  1027.74   998.3500  1027.31  1027.310000  3389000
# 3     2025-02-11  1020.79  1022.69  1002.9500  1008.08  1008.080000  3331800
# 4     2025-02-10  1023.05  1032.85  1015.8800  1027.60  1027.600000  3296600
# ...          ...      ...      ...        ...      ...          ...      ...
# 1252  2020-02-24   364.76   372.82   361.0000   368.70   368.700000  6936418
# 1253  2020-02-21   385.33   387.32   377.9008   380.07   380.070000  3935618
# 1254  2020-02-20   386.56   389.70   376.6800   386.00   386.000000  4079425
# 1255  2020-02-19   388.12   392.95   384.9000   386.19   386.190000  4896368
# 1256  2020-02-18   379.30   389.54   379.1900   387.78   387.779999  5180400
#
# ...
